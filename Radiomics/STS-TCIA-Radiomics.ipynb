# %% [markdown]
# # STS-TCIA-Radiomics
#
# Notebook com o proposito de passar dados dos paciente para um DataFrame e salvar em `.csv`.

# %% [markdown]
# ## Preparativos
#
# Importando bibliotecas para o funcionamento do programa.

# %%
import os
import radiomics
import logging
from radiomics import featureextractor
import pandas as pd
import json

# %% [markdown]
# Regular a verbosity de PyRadiomics (saídas para stderr).

# %%
radiomics.setVerbosity(logging.ERROR)

# %% [markdown]
# ## Set Extractor
#
# Setando `pyradiomics` para extrair features das imagens.

# %%
paramFile = "sts-settings1.yaml"
paramPath = os.path.join("..", "..", "data", "radiomics", paramFile)
print("Parameter file:", paramPath)

# Instantiate the extractor
extractor = featureextractor.RadiomicsFeatureExtractor(paramPath)

print("Extraction parameters:\n\t", extractor.settings)
print("Enabled filters:\n\t", extractor.enabledImagetypes)
print("Enabled features:\n\t", extractor.enabledFeatures)
# Out:
# Parameter file: ../../data/radiomics/sts-settings1.yaml
# Extraction parameters:
# 	 {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': True, 'normalizeScale': 100, 'removeOutliers': None, 'resampledPixelSpacing': [3, 3, 3], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'voxelArrayShift': 300, 'binWidth': 10}
# Enabled filters:
# 	 {'Original': {}, 'LoG': {'sigma': [3.0, 5.0]}, 'Wavelet': {}}
# Enabled features:
# 	 {'shape': None, 'firstorder': None, 'glcm': None, 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}

# %% [markdown]
# ## Set Diretório
#
# Estabelecendo local do diretório dos dados em uma variável.

# %%
data_root = os.path.join("..", "..", "data", "STS")

# %% [markdown]
# ## Agrupar caminhos
#
# Passando diretório por diretório, e montando um data frame com característica de cada par caminhos. Como fornecedor, paciente, tipo de imagem.

# %%
walk_files = pd.DataFrame(
    columns=["provider", "patient", "image_type", "walk_LABEL", "walk_IMAGE"])


labelSuffix = '-label'
filesExtension = '.nrrd'


for provider in os.listdir(data_root):
    walk_provider = os.path.join(data_root, provider)
    if os.path.isdir(walk_provider) and os.listdir(walk_provider):
        for patient in os.listdir(walk_provider):
            walk_patient = os.path.join(walk_provider, patient)
            if os.path.isdir(walk_patient) and os.listdir(walk_patient):
                for image_type in os.listdir(walk_patient):
                    walk_image_type = os.path.join(walk_patient, image_type)
                    if os.path.isdir(walk_image_type) and os.listdir(walk_image_type):
                        for file in os.listdir(walk_image_type):
                            if not os.path.isdir(file):
                                walk_file = os.path.join(walk_image_type, file)
                                if file.endswith(labelSuffix + filesExtension):
                                    walk_LABEL_file = walk_file
                                elif file.endswith(filesExtension):
                                    walk_IMAGE_file = walk_file
                        walk_files.loc[len(walk_files)] = [
                            provider, patient, image_type, walk_LABEL_file, walk_IMAGE_file]


walk_files
# Out:
#     provider  patient image_type  \
# 0       TCIA  STS_037         T1
# 1       TCIA  STS_037       STIR
# 2       TCIA  STS_047       T2FS
# 3       TCIA  STS_047         T1
# 4       TCIA  STS_029         T1
# ..       ...      ...        ...
# 97      TCIA  STS_033         T1
# 98      TCIA  STS_020         T1
# 99      TCIA  STS_020       STIR
# 100     TCIA  STS_051       T2FS
# 101     TCIA  STS_051         T1
#
#                                             walk_LABEL  \
# 0    ../../data/STS/TCIA/STS_037/T1/1 RTSTRUCT RTst...
# 1    ../../data/STS/TCIA/STS_037/STIR/1 RTSTRUCT RT...
# 2    ../../data/STS/TCIA/STS_047/T2FS/1 RTSTRUCT RT...
# 3    ../../data/STS/TCIA/STS_047/T1/1 RTSTRUCT RTst...
# 4    ../../data/STS/TCIA/STS_029/T1/1 RTSTRUCT RTst...
# ..                                                 ...
# 97   ../../data/STS/TCIA/STS_033/T1/1 RTSTRUCT RTst...
# 98   ../../data/STS/TCIA/STS_020/T1/1 RTSTRUCT RTst...
# 99   ../../data/STS/TCIA/STS_020/STIR/1 RTSTRUCT RT...
# 100  ../../data/STS/TCIA/STS_051/T2FS/1 RTSTRUCT RT...
# 101  ../../data/STS/TCIA/STS_051/T1/1 RTSTRUCT RTst...
#
#                                             walk_IMAGE
# 0      ../../data/STS/TCIA/STS_037/T1/3 AX TSE T1.nrrd
# 1      ../../data/STS/TCIA/STS_037/STIR/4 AX STIR.nrrd
# 2    ../../data/STS/TCIA/STS_047/T2FS/501 KNEE     ...
# 3    ../../data/STS/TCIA/STS_047/T1/601 KNEE       ...
# 4    ../../data/STS/TCIA/STS_029/T1/7 Axial T1  LT ...
# ..                                                 ...
# 97   ../../data/STS/TCIA/STS_033/T1/8 Axial FSET1 -...
# 98   ../../data/STS/TCIA/STS_020/T1/3 Coronal FSET1...
# 99   ../../data/STS/TCIA/STS_020/STIR/4 Coronal Fas...
# 100  ../../data/STS/TCIA/STS_051/T2FS/6 AXIAL  FSE ...
# 101  ../../data/STS/TCIA/STS_051/T1/5 AXIAL  T1- RE...
#
# [102 rows x 5 columns]

# %% [markdown]
# ## Montado dados
#
# Com o DataFrame `walk_files` podemos montar um novo dataframe com as features de cada tipo de imagem de cada paciente.
#
# Para isso precismos extrair as features de cada par de diretório e acrescentar no dataframe.

# %%
df_sts_tcia_rad = pd.DataFrame()
df_sts_tcia_rad["case_ID"] = walk_files.provider + \
    "-"+walk_files.patient+"-"+walk_files.image_type
df_sts_tcia_rad["case_ProviderID"] = walk_files.provider
df_sts_tcia_rad["case_PatientID"] = walk_files.patient
df_sts_tcia_rad["case_ImageType"] = walk_files.image_type

df_sts_tcia_rad.set_index("case_ID", inplace=True)
for index, label_path, image_path in zip(df_sts_tcia_rad.index, walk_files.walk_LABEL, walk_files.walk_IMAGE):
    radiomics = extractor.execute(image_path, label_path)
    for rad_key, rad_val in radiomics.items():
        if isinstance(rad_val, dict):
            df_sts_tcia_rad.loc[index, rad_key] = json.dumps(rad_val)
        elif isinstance(rad_val, tuple):
            df_sts_tcia_rad.loc[index, rad_key] = str(rad_val)
        else:
            df_sts_tcia_rad.loc[index, rad_key] = rad_val

df_sts_tcia_rad.sort_index()
# Out:
#                   case_ProviderID case_PatientID case_ImageType  \
# case_ID
# TCIA-STS_001-T1              TCIA        STS_001             T1
# TCIA-STS_001-T2FS            TCIA        STS_001           T2FS
# TCIA-STS_002-STIR            TCIA        STS_002           STIR
# TCIA-STS_002-T1              TCIA        STS_002             T1
# TCIA-STS_003-STIR            TCIA        STS_003           STIR
# ...                           ...            ...            ...
# TCIA-STS_049-T2FS            TCIA        STS_049           T2FS
# TCIA-STS_050-STIR            TCIA        STS_050           STIR
# TCIA-STS_050-T1              TCIA        STS_050             T1
# TCIA-STS_051-T1              TCIA        STS_051             T1
# TCIA-STS_051-T2FS            TCIA        STS_051           T2FS
#
#                   diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# case_ID
# TCIA-STS_001-T1                             v3.0.1                     1.21.5
# TCIA-STS_001-T2FS                           v3.0.1                     1.21.5
# TCIA-STS_002-STIR                           v3.0.1                     1.21.5
# TCIA-STS_002-T1                             v3.0.1                     1.21.5
# TCIA-STS_003-STIR                           v3.0.1                     1.21.5
# ...                                            ...                        ...
# TCIA-STS_049-T2FS                           v3.0.1                     1.21.5
# TCIA-STS_050-STIR                           v3.0.1                     1.21.5
# TCIA-STS_050-T1                             v3.0.1                     1.21.5
# TCIA-STS_051-T1                             v3.0.1                     1.21.5
# TCIA-STS_051-T2FS                           v3.0.1                     1.21.5
#
#                   diagnostics_Versions_SimpleITK  \
# case_ID
# TCIA-STS_001-T1                          2.1.1.2
# TCIA-STS_001-T2FS                        2.1.1.2
# TCIA-STS_002-STIR                        2.1.1.2
# TCIA-STS_002-T1                          2.1.1.2
# TCIA-STS_003-STIR                        2.1.1.2
# ...                                          ...
# TCIA-STS_049-T2FS                        2.1.1.2
# TCIA-STS_050-STIR                        2.1.1.2
# TCIA-STS_050-T1                          2.1.1.2
# TCIA-STS_051-T1                          2.1.1.2
# TCIA-STS_051-T2FS                        2.1.1.2
#
#                   diagnostics_Versions_PyWavelet diagnostics_Versions_Python  \
# case_ID
# TCIA-STS_001-T1                            1.3.0                      3.10.4
# TCIA-STS_001-T2FS                          1.3.0                      3.10.4
# TCIA-STS_002-STIR                          1.3.0                      3.10.4
# TCIA-STS_002-T1                            1.3.0                      3.10.4
# TCIA-STS_003-STIR                          1.3.0                      3.10.4
# ...                                          ...                         ...
# TCIA-STS_049-T2FS                          1.3.0                      3.10.4
# TCIA-STS_050-STIR                          1.3.0                      3.10.4
# TCIA-STS_050-T1                            1.3.0                      3.10.4
# TCIA-STS_051-T1                            1.3.0                      3.10.4
# TCIA-STS_051-T2FS                          1.3.0                      3.10.4
#
#                                   diagnostics_Configuration_Settings  \
# case_ID
# TCIA-STS_001-T1    {"minimumROIDimensions": 2, "minimumROISize": ...
# TCIA-STS_001-T2FS  {"minimumROIDimensions": 2, "minimumROISize": ...
# TCIA-STS_002-STIR  {"minimumROIDimensions": 2, "minimumROISize": ...
# TCIA-STS_002-T1    {"minimumROIDimensions": 2, "minimumROISize": ...
# TCIA-STS_003-STIR  {"minimumROIDimensions": 2, "minimumROISize": ...
# ...                                                              ...
# TCIA-STS_049-T2FS  {"minimumROIDimensions": 2, "minimumROISize": ...
# TCIA-STS_050-STIR  {"minimumROIDimensions": 2, "minimumROISize": ...
# TCIA-STS_050-T1    {"minimumROIDimensions": 2, "minimumROISize": ...
# TCIA-STS_051-T1    {"minimumROIDimensions": 2, "minimumROISize": ...
# TCIA-STS_051-T2FS  {"minimumROIDimensions": 2, "minimumROISize": ...
#
#                          diagnostics_Configuration_EnabledImageTypes  ...  \
# case_ID                                                               ...
# TCIA-STS_001-T1    {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# TCIA-STS_001-T2FS  {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# TCIA-STS_002-STIR  {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# TCIA-STS_002-T1    {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# TCIA-STS_003-STIR  {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# ...                                                              ...  ...
# TCIA-STS_049-T2FS  {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# TCIA-STS_050-STIR  {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# TCIA-STS_050-T1    {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# TCIA-STS_051-T1    {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
# TCIA-STS_051-T2FS  {"Original": {}, "LoG": {"sigma": [3.0, 5.0]},...  ...
#
#                   wavelet-LLL_gldm_LargeDependenceLowGrayLevelEmphasis  \
# case_ID
# TCIA-STS_001-T1                                             0.382355
# TCIA-STS_001-T2FS                                           0.000783
# TCIA-STS_002-STIR                                           0.005826
# TCIA-STS_002-T1                                             0.184798
# TCIA-STS_003-STIR                                           0.001594
# ...                                                              ...
# TCIA-STS_049-T2FS                                           0.000932
# TCIA-STS_050-STIR                                           0.001212
# TCIA-STS_050-T1                                             1.347635
# TCIA-STS_051-T1                                             0.247011
# TCIA-STS_051-T2FS                                           0.001380
#
#                   wavelet-LLL_gldm_LowGrayLevelEmphasis  \
# case_ID
# TCIA-STS_001-T1                                0.014371
# TCIA-STS_001-T2FS                              0.000306
# TCIA-STS_002-STIR                              0.001565
# TCIA-STS_002-T1                                0.007644
# TCIA-STS_003-STIR                              0.001085
# ...                                                 ...
# TCIA-STS_049-T2FS                              0.000187
# TCIA-STS_050-STIR                              0.000457
# TCIA-STS_050-T1                                0.012572
# TCIA-STS_051-T1                                0.007868
# TCIA-STS_051-T2FS                              0.000612
#
#                   wavelet-LLL_gldm_SmallDependenceEmphasis  \
# case_ID
# TCIA-STS_001-T1                                   0.111562
# TCIA-STS_001-T2FS                                 0.623462
# TCIA-STS_002-STIR                                 0.713815
# TCIA-STS_002-T1                                   0.283175
# TCIA-STS_003-STIR                                 0.665096
# ...                                                    ...
# TCIA-STS_049-T2FS                                 0.497140
# TCIA-STS_050-STIR                                 0.608473
# TCIA-STS_050-T1                                   0.043330
# TCIA-STS_051-T1                                   0.175143
# TCIA-STS_051-T2FS                                 0.653296
#
#                   wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis  \
# case_ID
# TCIA-STS_001-T1                                            13.895895
# TCIA-STS_001-T2FS                                        4077.229667
# TCIA-STS_002-STIR                                        7702.367375
# TCIA-STS_002-T1                                           256.102692
# TCIA-STS_003-STIR                                        5362.708021
# ...                                                              ...
# TCIA-STS_049-T2FS                                        5342.234253
# TCIA-STS_050-STIR                                        3893.434032
# TCIA-STS_050-T1                                             3.851515
# TCIA-STS_051-T1                                           156.567966
# TCIA-STS_051-T2FS                                        6913.274189
#
#                    wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis  \
# case_ID
# TCIA-STS_001-T1                                             0.002196
# TCIA-STS_001-T2FS                                           0.000234
# TCIA-STS_002-STIR                                           0.000616
# TCIA-STS_002-T1                                             0.002118
# TCIA-STS_003-STIR                                           0.000985
# ...                                                              ...
# TCIA-STS_049-T2FS                                           0.000115
# TCIA-STS_050-STIR                                           0.000359
# TCIA-STS_050-T1                                             0.000890
# TCIA-STS_051-T1                                             0.001398
# TCIA-STS_051-T2FS                                           0.000490
#
#                    wavelet-LLL_ngtdm_Busyness  wavelet-LLL_ngtdm_Coarseness  \
# case_ID
# TCIA-STS_001-T1                      4.370039                      0.000824
# TCIA-STS_001-T2FS                    0.098624                      0.000907
# TCIA-STS_002-STIR                    0.006910                      0.009653
# TCIA-STS_002-T1                      0.111926                      0.008068
# TCIA-STS_003-STIR                    0.014839                      0.004550
# ...                                       ...                           ...
# TCIA-STS_049-T2FS                    0.062109                      0.000489
# TCIA-STS_050-STIR                    0.056977                      0.002383
# TCIA-STS_050-T1                      2.487519                      0.001963
# TCIA-STS_051-T1                      0.154682                      0.003396
# TCIA-STS_051-T2FS                    0.019139                      0.003255
#
#                   wavelet-LLL_ngtdm_Complexity wavelet-LLL_ngtdm_Contrast  \
# case_ID
# TCIA-STS_001-T1                     301.427279                   0.046065
# TCIA-STS_001-T2FS                 54522.134897                   0.365681
# TCIA-STS_002-STIR                213222.857334                   0.815927
# TCIA-STS_002-T1                    4598.211806                   0.165676
# TCIA-STS_003-STIR                 77016.824576                   0.534899
# ...                                        ...                        ...
# TCIA-STS_049-T2FS                154586.417370                   0.137888
# TCIA-STS_050-STIR                 44438.458452                   0.737100
# TCIA-STS_050-T1                      69.371687                   0.015493
# TCIA-STS_051-T1                    6239.291511                   0.059259
# TCIA-STS_051-T2FS                165842.475951                   0.606025
#
#                   wavelet-LLL_ngtdm_Strength
# case_ID
# TCIA-STS_001-T1                     0.190421
# TCIA-STS_001-T2FS                   5.735231
# TCIA-STS_002-STIR                 261.107140
# TCIA-STS_002-T1                    15.788664
# TCIA-STS_003-STIR                  35.008041
# ...                                      ...
# TCIA-STS_049-T2FS                  16.089988
# TCIA-STS_050-STIR                  13.914988
# TCIA-STS_050-T1                     0.229804
# TCIA-STS_051-T1                    15.880346
# TCIA-STS_051-T2FS                  62.581853
#
# [102 rows x 1077 columns]

# %% [markdown]
# ## Exportando
#
# Com isso pronto exportamos em um `.csv`!

# %%
file_name = "STS-TCIA-Radiomics-" + paramFile[:-5] + ".csv"
df_sts_tcia_rad.to_csv(os.path.join('..', file_name))
